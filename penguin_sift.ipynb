# %%
import cv2
import numpy as np
#pip install opencv-contrib-python
import matplotlib.pyplot as plt

# %%
img = cv2.imread('penguin.jpeg')

# %%
plt.imshow(img)

# %%
sift = cv2.xfeatures2d.SIFT_create()

# %%
keypoints, descriptors = sift.detectAndCompute(img, None)

# %%
img_sift = cv2.drawKeypoints(img, keypoints, None, flags=4)

# %%
img_sift
# Out:
# array([[[176, 173, 159],
#         [169, 166, 152],
#         [159, 158, 144],
#         ...,
#         [185, 181, 170],
#         [163, 159, 148],
#         [146, 140, 127]],
#
#        [[171, 169, 158],
#         [165, 164, 150],
#         [159, 157, 146],
#         ...,
#         [190, 186, 175],
#         [178, 174, 163],
#         [172, 166, 153]],
#
#        [[175, 174, 164],
#         [170, 170, 158],
#         [164, 163, 153],
#         ...,
#         [183, 179, 168],
#         [171, 167, 156],
#         [166, 163, 149]],
#
#        ...,
#
#        [[114, 113, 103],
#         [101, 100,  90],
#         [117, 115, 104],
#         ...,
#         [ 74,  79,  77],
#         [117, 120, 118],
#         [ 78,  85,  80]],
#
#        [[134, 132, 121],
#         [147, 145, 134],
#         [178, 175, 161],
#         ...,
#         [143, 145, 145],
#         [179, 180, 178],
#         [162, 168, 163]],
#
#        [[176, 174, 163],
#         [176, 174, 163],
#         [169, 166, 152],
#         ...,
#         [160, 162, 162],
#         [156, 157, 155],
#         [147, 153, 148]]], dtype=uint8)

# %%
img_sift.shape
# Out:
# (243, 207, 3)

# %%
plt.imshow(img_sift, cmap=plt.cm.gray_r,interpolation='nearest')

# %%
cv2.imwrite("sift_img.jpg",img_sift)
# Out:
# True
